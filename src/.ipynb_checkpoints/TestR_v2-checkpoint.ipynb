# %% [markdown]
# # This is a test where GeoJSON is loaded in R, some statictics calculated and map plotted

# %% [markdown]
# # Load R libraries

# %%
library(ggplot2)
library(leaflet)

# %% [markdown]
# ## Import GeoJSON
# - use relative paths

# %%
# here() to define relative path based on project root 
lhd_tiles_geojson_path <- here::here("data", "lhd_tiles_1km_epsg25833.geojson") 

print(lhd_tiles_geojson_path)
# Out:
# [1] "B:/tarox03_user4/Muenzinger/3_jupyter/test_repo2docker/data/lhd_tiles_1km_epsg25833.geojson"

# %% [markdown]
# ## Imprt as SF

# %%
# function st_read
lhd_tiles_sf <- sf::st_read(lhd_tiles_geojson_path)
# Out:
# Reading layer `lhd_tiles_1km_epsg25833' from data source
#   `B:\tarox03_user4\Muenzinger\3_jupyter\test_repo2docker\data\lhd_tiles_1km_epsg25833.geojson'
#   using driver `GeoJSON'
# Simple feature collection with 397 features and 14 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: 4e+05 ymin: 5647000 xmax: 428000 ymax: 5671000
# Projected CRS: ETRS89 / UTM zone 33N

# %% [markdown]
# ## convert sf to data.table

# %%
# convert to data.table as firstly I do mainly data manipulation and plotting
lhd_tiles_dt <- data.table::as.data.table(lhd_tiles_sf)
lhd_tiles_dt
# Out:
#     OBJECTID FID_VG25_laender_UTM33N GEN     GEN_kurz FID_Kacheln_DE_1km
# 1    1       14                      Sachsen sn       7616
# 2    2       14                      Sachsen sn       7617
# 3    3       14                      Sachsen sn       7618
# 4    4       14                      Sachsen sn       7761
# 5    5       14                      Sachsen sn       7762
# 6    6       14                      Sachsen sn       7763
# 7    7       14                      Sachsen sn       7764
# 8    8       14                      Sachsen sn       7765
# 9    9       14                      Sachsen sn       7766
# 10  10       14                      Sachsen sn       7767
# 11  11       14                      Sachsen sn       7768
# 12  12       14                      Sachsen sn       7908
# 13  13       14                      Sachsen sn       7909
# 14  14       14                      Sachsen sn       7910
# 15  15       14                      Sachsen sn       7911
# 16  16       14                      Sachsen sn       7912
# 17  17       14                      Sachsen sn       7913
# 18  18       14                      Sachsen sn       7914
# 19  19       14                      Sachsen sn       7915
# 20  20       14                      Sachsen sn       7916
# 21  21       14                      Sachsen sn       7917
# 22  22       14                      Sachsen sn       7918
# 23  23       14                      Sachsen sn       8053
# 24  24       14                      Sachsen sn       8054
# 25  25       14                      Sachsen sn       8057
# 26  26       14                      Sachsen sn       8058
# 27  27       14                      Sachsen sn       8059
# 28  28       14                      Sachsen sn       8060
# 29  29       14                      Sachsen sn       8061
# 30  30       14                      Sachsen sn       8062
# ... ...      ...                     ...     ...      ...
# 368 368      14                      Sachsen sn       10934
# 369 369      14                      Sachsen sn       10935
# 370 370      14                      Sachsen sn       10936
# 371 371      14                      Sachsen sn       10937
# 372 372      14                      Sachsen sn       10938
# 373 373      14                      Sachsen sn       10939
# 374 374      14                      Sachsen sn       10940
# 375 375      14                      Sachsen sn       10941
# 376 376      14                      Sachsen sn       11129
# 377 377      14                      Sachsen sn       11130
# 378 378      14                      Sachsen sn       11131
# 379 379      14                      Sachsen sn       11132
# 380 380      14                      Sachsen sn       11133
# 27  1000000    413_5650 POLYGON ((414000 5650000, 4...
# 28  1000000    414_5650 POLYGON ((415000 5650000, 4...
# 29  1000000    415_5650 POLYGON ((416000 5650000, 4...
# 30  1000000    416_5650 POLYGON ((417000 5650000, 4...
# ... ...        ...      ...
# 368 1000000    415_5666 POLYGON ((416000 5666000, 4...
# 369 1000000    416_5666 POLYGON ((417000 5666000, 4...
# 370 1000000    417_5666 POLYGON ((418000 5666000, 4...
# 371 1000000    418_5666 POLYGON ((419000 5666000, 4...
# 372 1000000    419_5666 POLYGON ((420000 5666000, 4...
# 373 1000000    420_5666 POLYGON ((421000 5666000, 4...
# 374 1000000    421_5666 POLYGON ((422000 5666000, 4...
# 375 1000000    422_5666 POLYGON ((423000 5666000, 4...
# 376 1000000    413_5667 POLYGON ((414000 5667000, 4...
# 377 1000000    414_5667 POLYGON ((415000 5667000, 4...
# 378 1000000    415_5667 POLYGON ((416000 5667000, 4...
# 379 1000000    416_5667 POLYGON ((417000 5667000, 4...
# 380 1000000    417_5667 POLYGON ((418000 5667000, 4...
# 381 1000000    418_5667 POLYGON ((419000 5667000, 4...
# 382 1000000    419_5667 POLYGON ((420000 5667000, 4...
# 383 1000000    420_5667 POLYGON ((421000 5667000, 4...
# 384 1000000    421_5667 POLYGON ((422000 5667000, 4...
# 385 1000000    412_5668 POLYGON ((413000 5668000, 4...
# 386 1000000    413_5668 POLYGON ((414000 5668000, 4...
# 387 1000000    414_5668 POLYGON ((415000 5668000, 4...
# 388 1000000    415_5668 POLYGON ((416000 5668000, 4...
# 389 1000000    416_5668 POLYGON ((417000 5668000, 4...
# 390 1000000    420_5668 POLYGON ((421000 5668000, 4...
# 391 1000000    412_5669 POLYGON ((413000 5669000, 4...
# 392 1000000    413_5669 POLYGON ((414000 5669000, 4...
# 393 1000000    414_5669 POLYGON ((415000 5669000, 4...
# 394 1000000    415_5669 POLYGON ((416000 5669000, 4...
# 395 1000000    416_5669 POLYGON ((417000 5669000, 4...
# 396 1000000    412_5670 POLYGON ((413000 5670000, 4...
# 397 1000000    413_5670 POLYGON ((414000 5670000, 4...

# %% [markdown]
#  ## test aggregation

# %%
# convert to data.table as firstly I do mainly data manipulation and plotting
lhd_north_aggr <- lhd_tiles_dt[, .(count_cells = .N), by= c("North")]
lhd_north_aggr

# %% [markdown]
# # plot histogram

# %%
plot_histo <- ggplot2::ggplot(lhd_north_aggr, ggplot2::aes(x = North, y = count_cells, fill = count_cells)) +
  ggplot2::theme_bw()+
  ggplot2::geom_bar(stat = "identity", width = 0.7) 

plot_histo

# %% [markdown]
# # plot map
#
# # Note: leaflet works with RGB rasters or tiles, so we convert using rasterImage

# %%
# Make sure the data is in WGS84 (lat/lon)
lhd_tiles_sf <- sf::st_transform(lhd_tiles_sf, crs = 4326)

leaflet_plot <- leaflet(options = leafletOptions(minZoom = 2)) %>%
  addProviderTiles("CartoDB.Positron") %>%  # nice, clean basemap
  addPolygons(data= lhd_tiles_sf, color = "green")

leaflet_plot
